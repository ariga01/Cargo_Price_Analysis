# %%
import pandas as pd
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import AutoMinorLocator
import numpy as np

# %%
AUTO = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\AUTOINV.xlsx')
BOP = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\BOP.xlsx')
CE = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\CONSUMER_EXPECTATION.xlsx')
COVID = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\COVID.xlsx')
HHSE = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\HHSE.xlsx')
LA = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\LA.xlsx')
RETAIL = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\RETAILINV.xlsx')
T5Y = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\T5YIE.xlsx')
TF = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\TRUCK-FREIGHT.xlsx')
OIL = pd.read_excel('D:\Data\Project\Cargo Price Analysis\To Github\Raw Data\OIL.xlsx')

# %%
AUTO
# Out:
#           DATE  Ratio
# 0   2000-01-01  2.257
# 1   2000-02-01  2.089
# 2   2000-03-01  2.237
# 3   2000-04-01  2.307
# 4   2000-05-01  2.319
# ..         ...    ...
# 260 2021-09-01  0.448
# 261 2021-10-01  0.338
# 262 2021-11-01  0.188
# 263 2021-12-01  0.312
# 264 2022-01-01  0.171
#
# [265 rows x 2 columns]

# %%
AUTO.describe()
# Out:
#             Ratio
# count  265.000000
# mean     2.419962
# std      0.563037
# min      0.171000
# 25%      2.221000
# 50%      2.459000
# 75%      2.643000
# max      4.643000

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.gca()
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
ax.hist(AUTO['Ratio'],bins=40)
plt.show()
# Out:
# C:\Users\Test\AppData\Local\Temp\ipykernel_13596\1997890459.py:7: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.gca()
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.plot(AUTO['DATE'],AUTO['Ratio'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*, block=None)>
